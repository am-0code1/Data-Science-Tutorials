# %% [markdown]
# # Data visualization in Python
#
# ## Importance
# As an important subset of _data science_ field, _data visualization_ is the process of revealing trends, patterns, and correlations in a visual fashion. You may ask _why it matters_. Well, it turns out that _a picture is worth a thousand words_. You are most likely aware of this adage which basically says that complex and sometimes multiple ideas can be conveyed by a single still image more effectively than a mere verbal description [[1]](https://en.wikipedia.org/wiki/A_picture_is_worth_a_thousand_words).
#
# ## Scope of this tutorial
# In this tutorial, we discuss the basics of data visualization in Python. In particular, we introduce:
#
# <font color="green"> 1. Some of the most important Python libraries for data visualization including _pandas_, _matplotlib_, and _seaborn_.</font>
#
# <font color="blue"> 2. Some of the most important types of plots in data visualization including line plot, bar plot, histogram, boxplot, Kernel Density Estimation plot (density plot), area plot, pie plot, scatter plot, heatmap, scatter-matrix, scatter plot with side histograms, etc.
# </font>
#
# ## Structure of this tutorial
#
# First, we will start with a brief introduction of the _pandas_ library, since we will use it throughout this tutorial for creation and manipulation of the datasets that we use for data visualization demonstrations. We will then discuss the _pandas_ visualization and present some of the useful tools that _pandas_ library provides for data visualization in Python. We will, then, introduce the _seaborn_ library, followed by presenting some of its commonly-used features for data visualization.
#
# Last but not least, we will introduce the low-level library of _matplotlib_. In particular, we will show how flexible this library is when it comes to producing complex data visualizations and/or demanding customization of the format of plots. On the other hand, you will see how much time you can save by using high-level data visualization interfaces  provided by _pandas_ and _seaborn_, in case of dealing with typical data visualization tasks.

# %% [markdown]
# # Important Python libraries for data visualization
#
# In this section, we introduce some of the most important Python libraries for data visualization.
# In particular, _matplotlib_, _pandas_, and _seaborn_ are amongst the most commonly-used tools for data visualization in Python. Let's start with _pandas_.
#
# # Data visualization in Python | pandas visualization
# The _pandas_ library provides a fast and powerful tool for a vast variety of data analysis, manipulation, and even data visualization! Yes, _pandas_ enables you to accomplish most of the tasks of the data analysis pipeline:
#
# 1\. Loading dataset from different sources like a csv file or URL [More info](https://soardeepsci.com/python-pandas-read_csv-from-url/).
#
# 2\. Various analysis and manipulations such as  [sorting dataset by one or multiple columns](https://soardeepsci.com/how-to-sort-pandas-dataframe-by-multiple-columns/), [rolling 7 day average, monthly average, and so on](https://soardeepsci.com/a-hands-on-tutorial-for-data-science-learners-covid-19-dataset-part-5-groupby-grouper/),  [missing values analysis](https://soardeepsci.com/a-hands-on-tutorial-for-data-science-learners-covid-19-dataset-part-6-a-missing-values-analysis-b-data-visualization-matplotlib-barh/), etc.
#
# 3\. Various types of data visualization such as line plot, bar plot, histogram, boxplot, etc.
#
# The _pandas_ visualization is built on top of the _matplotlib_ library. That means, you can accomplish many of your data visualization tasks with _pandas_. However, _matplotlib_ can always be resorted to for complex data visualizations and/or customized configurations that may not be accessible by _pandas_.

# %% [markdown]
# ## Data visualization in Python | pandas visualization | examples
#
# In this section, we develop a sample _pandas DataFrame_ to represent our dataset. We will then demonstrate different types of plots for _pandas_ visualization.

# %% [markdown]
# ### Importing required libraries
# First, let's import the required libraries:

# %%
#importing pandas library
import pandas as pd

#importing matplotlib's pyplot module
import matplotlib.pyplot as plt

#importing seaborn library
import seaborn as sns

#importing numpy library
import numpy as np

# %% [markdown]
# Now, let's create a sample _DataFrame_ based on random numbers. We use the _NumPy_ library, here, for the purpose of generating random numbers.

# %%
num_points = 10
np.random.seed(123)
df = pd.DataFrame(np.random.randn(num_points, 3), index=np.arange(num_points), columns=list("ABC"))

print(f'Our sample DataFrame with {num_points} rows:')
df
# Out:
# Our sample DataFrame with 10 rows:
#           A         B         C
# 0 -1.085631  0.997345  0.282978
# 1 -1.506295 -0.578600  1.651437
# 2 -2.426679 -0.428913  1.265936
# 3 -0.866740 -0.678886 -0.094709
# 4  1.491390 -0.638902 -0.443982
# 5 -0.434351  2.205930  2.186786
# 6  1.004054  0.386186  0.737369
# 7  1.490732 -0.935834  1.175829
# 8 -1.253881 -0.637752  0.907105
# 9 -1.428681 -0.140069 -0.861755

# %% [markdown]
# ## Data visualization in Python | pandas visualization | line plot

# %% [markdown]
# You can produce a line-plot easily as shown below:

# %%
df.plot();

# %% [markdown]
# When working with _pandas_ visualization, note that the _DataFrame_ _plot_ method, plots a line-chart by default.
# You can specify what kind of plot to produce by passing the proper value to the argument _kind_.
# At the time of writing, the following types of plot is supported by _pandas_:
#
# 'line' : line plot (default)<br>
# 'bar' : vertical bar plot<br>
# ‘barh' : horizontal bar plot<br>
# 'hist' : histogram<br>
# 'box' : boxplot<br>
# 'kde' : Kernel Density Estimation plot<br>
# 'density' : same as ‘kde’<br>
# 'area' : area plot<br>
# 'pie' : pie plot<br>
# 'scatter' : scatter plot (DataFrame only)<br>
# 'hexbin' : hexbin plot (DataFrame only)<br>

# %% [markdown]
# ## Data visualization in Python | pandas visualization | bar plot

# %% [markdown]
# Let's plot a bar-chart now:

# %%
df.plot(kind='bar');

# %% [markdown]
# You can also produce the bar-plot for a given row of dataset:

# %%
df.iloc[5].plot(kind='bar');

# %% [markdown]
# Alternatively, you could use the _bar_ method for producing a bar plot:

# %%
df.plot.bar();

# %% [markdown]
# ## Data visualization in Python | pandas visualization | stacked bar plot

# %% [markdown]
# You can pass _stacked=True_ for producing a stacked bar plot:

# %%
df.plot.bar(stacked=True);

# %% [markdown]
# ## Data visualization in Python | pandas visualization | horizontal bar plot

# %% [markdown]
# Similarly, you can use the _barh_ method, or pass the kind='barh' to plot a horizontal bar-chart:

# %%
df.plot.barh();
#df.plot(kind='barh');

# %% [markdown]
# ## Data visualization in Python | pandas visualization | stacked horizontal bar plot

# %% [markdown]
# In a similar fashion, you can produce a stacked horizontal bar-plot:

# %%
df.plot.barh(stacked=True);

# %% [markdown]
# ## Data visualization in Python | pandas visualization | formatting of plot

# %% [markdown]
# It is worth mentioning that the _pandas DataFrame plot_ method has numerous keyword arguments to control the formatting of the returned plot, some of which are shown in the following:

# %%
df.plot(
    kind='bar',
    figsize=(6,4), # size of figure (width, height) in inches
    xlabel='Label for x-axis', 
    ylabel='Label for y-axis', 
    title='Title for figure',
    fontsize=13,
    rot=45, #rotation for ticks
    alpha=0.5, #transparency of a graph plot
    );

# %% [markdown]
# ## Data visualization in Python | pandas visualization | area plot

# %% [markdown]
# You can create an area plot using the method _area_ or by passing _kind=area_ to the method _plot_. Note that _stacked=True_ is an option only when all columns are all positive or negative (not a mixture of both).

# %%
df.plot.area(stacked=False);
#df.plot(kind='area', stacked=False);

# %% [markdown]
# ## Data visualization in Python | pandas visualization | scatter plot

# %% [markdown]
# You can draw scatter plot by using the _scatter_ method or passing _kind=scatter_ to the _plot_ method.
# Note that scatter plot needs numeric columns for both x and y axes to be specified by the x and y keywords.

# %%
df.plot.scatter(x="A", y="B");
#df.plot(kind='scatter', x="A", y="B");

# %% [markdown]
# ## Data visualization in Python | pandas visualization | formatting of scatter plot

# %% [markdown]
# Here is some formatting for the scatter plot:<br>
# c: color of each point<br>
# s: size of each point<br>
# cmap: type of colormap<br>

# %%
df.plot.scatter(x="A", y="B", c="C", cmap="viridis", s=150);

# %% [markdown]
# You could also impose a variable size of points based on their corresponding values in a given column or a function:

# %%
df.plot.scatter(x="A", y="B", c="C", cmap="viridis", s=150*df.C.apply(lambda x: x**2));

# %% [markdown]
# ## Data visualization in Python | pandas visualization | boxplot

# %% [markdown]
# You can produce a boxplot in _pandas_ using the _boxplot_ method or the _plot_ method and the key='box' argument.

# %%
df.boxplot(grid=False);#feel free to use grid=True to see the difference
#df.plot(kind='box', grid=False);

# %% [markdown]
# ## Data visualization in Python | pandas visualization | histograms

# %% [markdown]
# Let's create a new dataframe with much more data points suitable for a histogram demonstration:

# %%
np.random.seed(123)
df1 = pd.DataFrame(
    {
        "a": np.random.randn(1000) +1,
        "b": np.random.randn(1000),
        "c": np.random.randn(1000) - 1,
    },
    columns=["a", "b", "c"],
)

# %% [markdown]
# You can draw histograms using the plot _hist_ method or by passing _kind='hist'_ to the _plot_ method:

# %%
df1.plot(kind='hist', alpha=0.5);
#df1.plot.hist(alpha=0.5);

# %% [markdown]
# You can draw a stacked histogram by passing _stacked=True_. The number of bins can also be altered using the _bins_ keyword.

# %%
df1.plot(kind='hist', stacked=True, bins=25);
#df1.plot.hist(stacked=True, bins=25);

# %%
df1.plot(kind='hist', stacked=False, bins=25);
#df1.plot.hist(stacked=False, bins=25);

# %% [markdown]
# ## Data visualization in Python | pandas visualization | KDE plot

# %% [markdown]
# Here is how you can produce a density or Kernel Density Estimation plot by passing _kind='kde'_ or _kind='density'_:

# %%
df1.plot(kind='kde');
#df1.plot(kind='density');

# %% [markdown]
# In case a subset of columns needs to be plotted:

# %%
df1[['a', 'c']].plot(kind='kde');

# %% [markdown]
# ## Data visualization in Python | pandas visualization | scatter matrix plot
#
# The scatter matrix plot is especially helpful, since it enables you to plot a grid of pairwise correlations in dataset.
# You can produce a scatter plot matrix by using the scatter_matrix method from the _pandas.plotting_ module:

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(df1, alpha=0.9, figsize=(8, 8), s=100, diagonal="kde");

# %% [markdown]
# ## Data visualization in Python | pandas visualization | pie chart
#
# Let's create another dataframe more suitable for a pie chart:

# %%
df2 = pd.DataFrame({'Sales': [70, 30 , 55, 20],
                   'Profit': [700, 600, 1550, 100]},
                  index=['Product-A', 'Product-B', 'Product-C', 'Product-D'])
df2
# Out:
#            Sales  Profit
# Product-A     70     700
# Product-B     30     600
# Product-C     55    1550
# Product-D     20     100

# %% [markdown]
# Here is how to plot pie chart using _pandas_:

# %%
df2.plot.pie(y='Profit', figsize=(5, 5));

# %%
df2.plot.pie(y='Profit', figsize=(5, 5),
             labels=None,
             autopct="%.2f",
             fontsize=16,
            );

# %% [markdown]
# Note that _pandas_ visualization is built on top of _matplotlib_ library. It mainly wraps _matplotlib_ methods with some acceptable flexibility of formatting and customization. However, at the time of writing, the placement of legend is not yet flexible through _pandas_. One can still directly use the features that the _matplotlib_ library provides. For example, we can adjust the legend positioning using the _legend_ method:

# %%
df2.plot.pie(y='Profit', figsize=(5, 5));
plt.legend(loc='lower right');

# %% [markdown]
# You can also make separate subplots for each column:

# %%
df2.plot.pie(subplots=True, figsize=(13, 5));

# %% [markdown]
# You may not like the format of this plot, mainly due to the overlap of legends with the pie-chart, as well as the overlap of labels "Sales" and "Product-B".
#
# Again, a detailed customization of plot's format through _pandas_ may be tricky. For such complex plots and/or formatting, you may prefer using _matplotlib_ library directly, since it provides you with all low-level features and options.

# %% [markdown]
# ## Data visualization in Python | pandas visualization | useful resources
#
# You can find very helpful resources consisting of example plots and source codes from the _pandas_ user guide for [chart visualization](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html) or [table visualization](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html), as well as
# [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/cookbook.html#cookbook-plotting),
# [here](https://pandas.pydata.org/pandas-docs/version/0.15/tutorials.html),
# and
# [here](https://pandas.pydata.org/pandas-docs/stable/ecosystem.html#ecosystem-visualization).

# %% [markdown]
# # Data visualization in Python | visualization with seaborn
#
# _Seaborn_ is a Python data visualization library built on top of _matplotlib_. That is, _Seaborn_ provides a high-level interface enabling you to draw attractive and informative statistical graphics with a relatively small amount of coding.
#
# In the following, we will present some of the data visualization capabilities provided by _seaborn_.

# %% [markdown]
# ## Data visualization in Python | visualization with seaborn | line plot

# %% [markdown]
# You can get a report on available example datasets provided by _seaborn_ as shown below:

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# For this example, let's work with the _iris_ dataset from _seaborn_:

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Here is how to produce a line plot in _seaborn_ to show _petal length_ versus _petal width_ for different classes of species:

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x="petal_width", y="petal_length", hue="species", data=iris);

# %% [markdown]
# You can see how easy it is to produce a high-quality graph with lots of cool pre-defined formatting features.

# %% [markdown]
# ## Data visualization in Python | visualization with seaborn | grouped bar plots

# %% [markdown]
# Let's load the _penguins_ dataset from _seaborn_:

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# Here is how to draw grouped bar plot with error bars in _seaborn_:

# %%
splt = sns.catplot(data=penguins, kind="bar",
    x="species", y="body_mass_g", hue="sex",
    ci="sd", palette="dark", alpha=.45, height=5
)
splt.set_axis_labels("", "Body mass (g)");

# %% [markdown]
# ## Data visualization in Python | visualization with seaborn | grouped boxplots

# %% [markdown]
# Let's load the _tips_ dataset from _seaborn_:

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Here is how to draw grouped boxplots in _seaborn_:

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips);

# %% [markdown]
# ## Data visualization in Python | visualization with seaborn | boxenplot

# %% [markdown]
# Let's load the _diamonds_ dataset from _seaborn_:

# %%
diamonds = sns.load_dataset("diamonds")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# We can get the list of _clarity_ classes from:

# %%
clarity_classes = list(diamonds.clarity.unique())
clarity_classes
# Out:
# ['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF']

# %% [markdown]
# Now, we can use the _seaborn boxenplot_ to draw an enhanced box plot for relatively large datasets, like the _diamonds_ dataset:

# %%
sns.boxenplot(x="clarity", y="carat",
              color="b", order=clarity_classes,
              scale="linear", data=diamonds);

# %% [markdown]
# ## Data visualization in Python | visualization with seaborn | kernel density with marginal histograms
#
# By using _seaborn_, you can easily draw density plots on side(s) of a main plot. For example, in the following, you see how to draw kernel density plot with marginal histograms in _seaborn_:

# %%
g = sns.JointGrid(data=penguins, x="body_mass_g", y="bill_depth_mm", space=0.1)
g.plot_joint(sns.kdeplot, fill=True, cmap="hot");
g.plot_marginals(sns.histplot, color="darkred", alpha=0.6, bins=20);

# %% [markdown]
# ## Data visualization in Python | visualization with seaborn | annotated heatmaps
#
# You can create annotated heatmaps in _seaborn_ as shown below:

# %%
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, cmap='hot', fmt="d", linewidths=.5, ax=ax);

# %% [markdown]
# ## Data visualization in Python | visualization with seaborn visualization | useful resources
#
# You can find very helpful resources consisting of example plots and source codes from the _seaborn_'s [introduction](https://seaborn.pydata.org/introduction.html), [tutorial](https://seaborn.pydata.org/tutorial.html), as well as
# [example gallery](https://seaborn.pydata.org/examples/index.html) pages.

# %% [markdown]
# # Data visualization in Python | visualization with matplotlib
#
# _Matplotlib_ is a comprehensive and open-source library for producing various types of visualizations in Python.
# It is important to know what version of _matplotlib_ you have on your system.
# Some of the features we use in the following like "bar_label" have been recently added to _matplotlib_ at the time of writing.
# In case you have an older version of _matplotlib_, you can upgrade it using _pip_.
# Alternatively, you could just comment those lines with such features in the following code, and you should be fine.
# Here is how to know matplotlib's version on your system:

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.5.0'

# %% [markdown]
# ## Data visualization in Python | visualization with matplotlib | grouped bar chart with labels

# %% [markdown]
# As an example, let's say we have the sales data for two products: Product-A and Product-B over four quarters:

# %%
PA_means = [80, 64, 55, 65]
PB_means = [65, 72, 61, 85]

# %% [markdown]
# And, here is the total sales:

# %%
tot_sales = []
for ind, item in enumerate(PA_means):
    tot_sales.append(PA_means[ind]+PB_means[ind])
print(f'Total sales: {tot_sales}')
# Out:
# Total sales: [145, 136, 116, 150]

# %% [markdown]
# Here is a Python code snippet for producing a bar plot for this data:

# %%
labels = ['$Q_1$', '$Q_2$', '$Q_3$', '$Q_4$']

# label locations: 1, 2, 3, and 4
x = np.arange(len(labels))

# width of bars
bar_width = 0.25

fig, ax = plt.subplots()
bar1 = ax.bar(x - bar_width/2, PA_means, bar_width, label='Product-A')
bar2 = ax.bar(x + bar_width/2, PB_means, bar_width, label='Product-B')

# setting the y-axis labels
ax.set_ylabel('Sales')

# setting title of figure
ax.set_title('Sales of Products A & B over four Quarters')

# setting values
ax.set_xticks(x)

# setting x-axis tick labels
ax.set_xticklabels(labels)

# limit of y-axis
ax.set_ylim(0, 100)

# adding legend with customized location
ax.legend(loc="upper center")

# adding labels on top of bars
ax.bar_label(bar1, padding=3)
ax.bar_label(bar2, padding=3)

# adjust the padding
fig.tight_layout()

# %% [markdown]
# You can see there are so many features and options provided by _matplotlib_, enabling the customization of plot's format with a high level of flexibility. That is great!

# %% [markdown]
# ## Data visualization in Python | visualization with matplotlib | stacked bar chart with labels

# %% [markdown]
# Now, let's see how to create a stacked bar plot with error bars. Let us assume the following standard deviations for the sales data:

# %%
PA_std = [10, 5, 8, 5]
PB_std = [5, 10, 5, 8]
tot_std = [12, 12, 10, 10]

# %%
fig, ax = plt.subplots(figsize=(9,5))

bar1 = ax.bar(labels, PA_means, bar_width, yerr=PA_std, label='Product-A')
bar2 = ax.bar(labels, PB_means, bar_width, yerr=PB_std, bottom=PA_means, label='Product-B')

ax.set_ylabel('Sales')
ax.set_title('Sales of Products A & B over four Quarters')
ax.legend()

# creating a list for labels on top of bars
list_label = []
for ind in range(len(PA_std)):
    list_label.append('%.1f$\pm$%.1f'% (tot_sales[ind], tot_std[ind]))

# adding label on top of bars
ax.bar_label(bar2, labels=list_label,
             padding=0, color='b', fontsize=12);

# setring the upper limit of y-axis
ax.set_ylim(top=220);

# %% [markdown]
# ## Data visualization in Python | visualization with matplotlib | horizontal bar chart with labels

# %%
labels = ['$Q_1$', '$Q_2$', '$Q_3$', '$Q_4$']

# label locations: 1, 2, 3, and 4
y = np.arange(len(labels))

# width of bars
bar_width = 0.25

fig, ax = plt.subplots()
bar1 = ax.barh(y - bar_width/2, PA_means, bar_width,  xerr=PA_std, label='Product-A')
bar2 = ax.barh(y + bar_width/2, PB_means, bar_width,  xerr=PA_std, label='Product-B')

# setting the y-axis labels
ax.set_ylabel('Sales')

# setting title of figure
ax.set_title('Sales of Products A & B over four Quarters')

# setting values
ax.set_yticks(y)

# setting x-axis tick labels
ax.set_yticklabels(labels)

# limit of axis
ax.set_xlim(0, 120)
ax.set_ylim(top=3.7)

# adding legend with customized location
ax.legend(loc='center right')

# creating a list for labels on top of bars
list_labelA = []
list_labelB = []
for ind in range(len(PA_std)):
    list_labelA.append('%.1f$\pm$%.1f'% (PA_means[ind], PA_std[ind]))
    list_labelB.append('%.1f$\pm$%.1f'% (PB_means[ind], PB_std[ind]))

# adding labels on top of bars
ax.bar_label(bar1, labels=list_labelA, padding=2, color='blue', fontsize=12)
ax.bar_label(bar2, labels=list_labelB, padding=2, color='brown', fontsize=12)

# labels read top-to-bottom
ax.invert_yaxis() 

# adjust the padding
fig.tight_layout()

# %% [markdown]
# ## Data visualization in Python | visualization with matplotlib | line chart

# %% [markdown]
# Let's create a sample dataset for this data visualization task:

# %%
np.random.seed(123)
dfm1 = pd.DataFrame(
    {
        "a": np.random.randn(1000),
        "b": np.random.randn(1000),
        "c": np.random.randn(1000),
    },
    columns=["a", "b", "c"],
)

def classify(x):
    this_class = 0
    if x[0] + x[1] > 1.5:
        this_class = 1;
    elif x[0]<0:
        this_class = 2;
    elif x[1]<0:
        this_class = 3;
    return this_class

dfm1['class'] = dfm1.apply(classify, axis=1)
dfm1
# Out:
#             a         b         c  class
# 0   -1.085631 -0.748827 -1.774224      2
# 1    0.997345  0.567595 -1.201377      1
# 2    0.282978  0.718151  1.096257      0
# 3   -1.506295 -0.999381  0.861037      2
# 4   -0.578600  0.474898 -1.520367      2
# ..        ...       ...       ...    ...
# 995  0.634763  0.845701 -0.075335      0
# 996  1.069919 -1.119923 -0.946199      3
# 997 -0.909327 -0.359297  2.040432      2
# 998  0.470264 -1.609695  1.015917      3
# 999 -1.111430  0.013570 -1.633788      2
#
# [1000 rows x 4 columns]

# %% [markdown]
# Here is a Python code example showing how to draw a line chart:

# %%
dfm1[['a', 'b', 'c']].cumsum()
# Out:
#              a          b          c
# 0    -1.085631  -0.748827  -1.774224
# 1    -0.088285  -0.181233  -2.975601
# 2     0.194693   0.536918  -1.879344
# 3    -1.311601  -0.462463  -1.018307
# 4    -1.890202   0.012435  -2.538674
# ..         ...        ...        ...
# 995 -39.083561  11.464512   9.876729
# 996 -38.013642  10.344589   8.930530
# 997 -38.922969   9.985292  10.970962
# 998 -38.452706   8.375597  11.986879
# 999 -39.564136   8.389167  10.353090
#
# [1000 rows x 3 columns]

# %%
plt.plot(dfm1[['a', 'b', 'c']].cumsum(), label=dfm1.columns[:-1])
plt.ylabel('Cumulative sum')
plt.xlabel('Index of data point');
plt.legend(loc='lower left');
plt.title('cumulative sum of a, b, and c');

# %% [markdown]
# ## Data visualization in Python | visualization with matplotlib | subplots

# %% [markdown]
# Here is the Python code example demonstrating how to create subplots with some formatting:

# %%
linestyle='solid'
color='k'
linewidth=2
marker='o'
markevery=25
markersize=12
markeredgewidth=1
markeredgecolor = 'k'
markerfacecolor='orangered'

fig, ax = plt.subplots(3,1, figsize=(12,8))

ax[0].plot(dfm1.a.cumsum(), 
           linestyle=linestyle, color=color, linewidth=linewidth,
           marker=marker, markevery=markevery, 
           markersize=markersize, markeredgewidth=markeredgewidth,
           markeredgecolor = markeredgecolor, 
           markerfacecolor='yellow')
ax[0].tick_params(axis='y', which='major', labelsize=16)
ax[0].tick_params(axis='x', which='major', labelsize=0)
ax[0].grid(axis='x')
ax[0].set_ylabel('a', fontsize=20)
ax[0].set_title('Cumulative sum', fontsize=20)

ax[1].plot(dfm1.b.cumsum(), 
           linestyle=linestyle, color=color, linewidth=linewidth,
           marker='D', markevery=markevery, 
           markersize=markersize, markeredgewidth=markeredgewidth,
           markeredgecolor = markeredgecolor, 
           markerfacecolor='lightblue')
ax[1].tick_params(axis='y', which='major', labelsize=16)
ax[1].tick_params(axis='x', which='major', labelsize=0)
ax[1].grid(axis='x')
ax[1].set_ylabel('b', fontsize=20)

ax[2].plot(dfm1.c.cumsum(), 
           linestyle=linestyle, color=color, linewidth=linewidth,
           marker='p', markevery=markevery, 
           markersize=markersize, markeredgewidth=markeredgewidth,
           markeredgecolor = markeredgecolor, 
           markerfacecolor='lightgreen')
ax[2].tick_params(axis='y', which='major', labelsize=16)
ax[2].tick_params(axis='x', which='major', labelsize=16)
ax[2].grid(axis='x')
ax[2].set_ylabel('c', fontsize=20)
ax[2].set_xlabel('Index of data point', fontsize=20)

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.2)

# %% [markdown]
# ## Data visualization in Python | visualization with matplotlib | scatter plot

# %% [markdown]
# Here is a Python code example for drawing scatter plot:

# %%
plt.scatter(dfm1.a, dfm1.b);

# %% [markdown]
# The following Python code example demonstrates how to customize the scatter plot flexibly. More detailed information on different types of colormaps can be found from [here](https://matplotlib.org/stable/tutorials/colors/colormaps.html).

# %%
fig, ax = plt.subplots(2,2,figsize=(12,9))

sbp = ax[0,0].scatter(dfm1.a, dfm1.b, s=dfm1.c.apply(lambda x: 100*np.sqrt(x**2)), 
            c=dfm1.c, cmap='viridis', alpha=0.5);
fig.colorbar(sbp, ax=ax[0,0]);
ax[0,0].axis('equal');

sbp = ax[0,1].scatter(dfm1.a, dfm1.b, s=dfm1.c.apply(lambda x: 100*np.sqrt(x**2)), 
            c=dfm1.c, cmap='hot', alpha=0.5);
fig.colorbar(sbp, ax=ax[0,1]);
ax[0,1].axis('equal');

sbp = ax[1,0].scatter(dfm1.a, dfm1.b, s=dfm1.c.apply(lambda x: 100*np.sqrt(x**2)), 
            c=dfm1.c, cmap='plasma', alpha=0.5);
fig.colorbar(sbp, ax=ax[1,0]);
ax[1,0].axis('equal');

sbp = ax[1,1].scatter(dfm1.a, dfm1.b, s=dfm1.c.apply(lambda x: 100*np.sqrt(x**2)), 
            c=dfm1.c, cmap='binary', alpha=0.75);
fig.colorbar(sbp, ax=ax[1,1]);
ax[1,1].axis('equal');
# Out:
# <ipython-input-52-2759108c9917>:5: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   fig.colorbar(sbp, ax=ax[0,0]);
# <ipython-input-52-2759108c9917>:10: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   fig.colorbar(sbp, ax=ax[0,1]);
# <ipython-input-52-2759108c9917>:15: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   fig.colorbar(sbp, ax=ax[1,0]);
# <ipython-input-52-2759108c9917>:20: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
# ...

# %% [markdown]
# Regarding the warning message you see here, the version 3.5 is fairly new at the time of writing, and calling _grid(False)_ does not help despite the instruction provided in the warning message. The issue seems to be a bug which will be hopefully fixed by the _matplotlib_ developers in near future.

# %% [markdown]
# ## Data visualization in Python | visualization with matplotlib | scatter plot with histograms

# %% [markdown]
# Scatter plot with histograms is another type insightful plot that can be produced using _matplotlib_.
# It consists of a scatter plot with marginal distributions of a scatter as histograms at the sides of the plot.
# The following Python code example demonstrate how to produce a scatter plot with histograms.

# %%
def sc_hist(x, y, ax_sc, ax_hx, ax_hy, bin_size = 0.3, opt_format=False):
    # turning off target tick labels
    ax_hx.tick_params(axis="x", labelbottom=False)
    ax_hy.tick_params(axis="y", labelleft=False)

    # main scatter plot with some formatting:
    if opt_format:
        ax_sc.scatter(x, y, s=60, c=dfm1['class'], cmap='viridis', 
                      edgecolor='black', linewidth=1, alpha=0.3)
    else:
        ax_sc.scatter(x, y)

    # finding limits
    tot_max = max(np.max(np.abs(x)), np.max(np.abs(y)))
    half_span = (int(tot_max/bin_size) + 1) * bin_size
    
    array_bins = np.arange(-half_span, half_span + bin_size, bin_size)
    ax_hx.hist(x, bins=array_bins)
    ax_hy.hist(y, bins=array_bins, orientation='horizontal')
    
# config of axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.02

# rectangular frame for scatter and histogram plots
frame_sc = [left, bottom, width, height]
frame_hx = [left, bottom + height + spacing, width, 0.2]
frame_hy = [left + width + spacing, bottom, 0.2, height]

# initializing the figure
fig = plt.figure(figsize=(8, 8))

# adding frames to figure
ax_sc = fig.add_axes(frame_sc)
ax_hx = fig.add_axes(frame_hx, sharex=ax_sc)
ax_hy = fig.add_axes(frame_hy, sharey=ax_sc)

#----------------------------------------
# creating scatter and histogram plots 
# using the developed function above
#----------------------------------------
sc_hist(x=dfm1.a, y=dfm1.b, ax_sc=ax_sc, ax_hx=ax_hx, ax_hy=ax_hy, bin_size=0.3)

# %% [markdown]
# And, here is the same plot with some formatting to specify the color of data points based on their class:

# %%
# config of axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.02

# rectangular frame for scatter and histogram plots
frame_sc = [left, bottom, width, height]
frame_hx = [left, bottom + height + spacing, width, 0.2]
frame_hy = [left + width + spacing, bottom, 0.2, height]

# initializing the figure
fig = plt.figure(figsize=(8, 8))

# adding frames to figure
ax_sc = fig.add_axes(frame_sc)
ax_hx = fig.add_axes(frame_hx, sharex=ax_sc)
ax_hy = fig.add_axes(frame_hy, sharey=ax_sc)

#----------------------------------------
# creating scatter and histogram plots 
# using the developed function above
#----------------------------------------
sc_hist(x=dfm1.a, y=dfm1.b, ax_sc=ax_sc, ax_hx=ax_hx, ax_hy=ax_hy, bin_size=0.3, opt_format=True)

# %% [markdown]
# ## Data visualization in Python | visualization with matplotlib | discrete distribution as horizontal bar chart

# %% [markdown]
# Let us quickly create a DataFrame representing our sample dataset for the rating data on multiple movies:

# %%
class_list = ['Great', 'Good', 'Fair', 'Neutral', 'Bad']
movie_list = ['Movie #1', 'Movie #2', 'Movie #3', 'Movie #4', 'Movie #5']

np.random.seed(123)
num_movies = 5
data = np.random.randint(0,100, size=(num_movies, len(class_list)))

df_rating = pd.DataFrame(data, columns=class_list, index=movie_list)
df_rating['Total'] = df_rating.sum(axis=1)
df_rating
# Out:
#           Great  Good  Fair  Neutral  Bad  Total
# Movie #1     66    92    98       17   83    356
# Movie #2     57    86    97       96   47    383
# Movie #3     73    32    46       96   25    272
# Movie #4     83    78    36       96   80    373
# Movie #5     68    49    55       67    2    241

# %% [markdown]
# And, here is the same dataset presented in a percentage-wise fashion.

# %%
df_rating_percentage = 100*df_rating.iloc[:,:-1].div(df_rating.Total, axis=0)
df_rating_percentage['Total'] = df_rating_percentage.sum(axis=1)
df_rating_percentage
# Out:
#               Great       Good       Fair    Neutral        Bad  Total
# Movie #1  18.539326  25.842697  27.528090   4.775281  23.314607  100.0
# Movie #2  14.882507  22.454308  25.326371  25.065274  12.271540  100.0
# Movie #3  26.838235  11.764706  16.911765  35.294118   9.191176  100.0
# Movie #4  22.252011  20.911528   9.651475  25.737265  21.447721  100.0
# Movie #5  28.215768  20.331950  22.821577  27.800830   0.829876  100.0

# %% [markdown]
# The following Python code snippet shows you how to create horizontal bar chart for discrete distributions:

# %%
def plot_rating(df, class_names, cmap = 'RdYlGn_r', label_num_dec_place=0):
    df=df.copy()
    df_cumsum = df.cumsum(axis=1)
    format_label = f"%.{label_num_dec_place}f"
    
    class_colors = plt.colormaps[cmap](np.linspace(0, 1, df.shape[1]))

    fig, ax = plt.subplots(figsize=(8, 5))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_xlim(0, np.sum(df, axis=1).max())

    for ind, (this_colname, this_color) in enumerate(zip(class_names, class_colors)):
        this_widths = df.iloc[:, ind]
        this_starts = df.cumsum(axis=1).iloc[:,ind] - this_widths
        this_labels = [f'{format_label}' % e for e in this_widths]
        bars = ax.barh(list(df.index), this_widths, left=this_starts, 
                       height=0.4, label=this_colname, color=this_color)

        r, g, b, _ = this_color
        text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
        ax.bar_label(bars, labels=this_labels, label_type='center', fontsize=14, color=text_color)
    ax.legend(ncol=len(class_names), loc='lower center', bbox_to_anchor=(0.5, 1), fontsize='medium')
    plt.yticks(rotation=20, fontsize=14)
    return fig, ax

plot_rating(df_rating[df_rating.columns[:-1]], class_list);

# %% [markdown]
# You can pass the percentage-based dataset to the same function to produce the corresponding horizontal bar plot for that dataset.

# %%
plot_rating(df_rating_percentage[df_rating_percentage.columns[:-1]], class_list,
            cmap = 'RdYlGn_r',
            label_num_dec_place=1);

# %% [markdown]
# ## Data visualization in Python | visualization with matplotlib | annotated heatmaps

# %% [markdown]
# Let us create two datasets representing our sales data related to different products and stores for two different time intervals:

# %%
index_labels = ["Product #1", "Product #2", "Product #3", "Product #4",
              "Product #5", "Product #6", "Product #7", "Product #8"]
column_labels = ["Store #1", "Store #2", "Store #3",
           "Store #4", "Store #5", "Store #6", "Store #7", "Store #8"]

np.random.seed(12345)
data_hm1 = np.random.randint(0,100, size=(len(column_labels), len(column_labels)))
np.random.seed(54321)
data_hm2 = np.random.randint(0,100, size=(len(column_labels), len(column_labels)))

df_hm1 = pd.DataFrame(data=data_hm1, columns=column_labels, index=index_labels)
df_hm2 = pd.DataFrame(data=data_hm2, columns=column_labels, index=index_labels)

# %% [markdown]
# Here is the first dataset:

# %%
df_hm1
# Out:
#             Store #1  Store #2  Store #3  Store #4  Store #5  Store #6  \
# Product #1        98        29         1        36        41        34
# Product #2        59        14        91        80        73        11
# Product #3        81        82        38         7        43        23
# Product #4        55        31        61        97        91        87
# Product #5         3         5        15        75        14        81
# Product #6        53        72         5        98         5        59
# Product #7        14        80        27        38        88        96
# Product #8        76        22        12        62        41        18
#
#             Store #7  Store #8
# Product #1        29         1
# Product #2        77        10
# Product #3        29        56
# Product #4        36        64
# Product #5         5        34
# Product #6        83        12
# Product #7         5        74
# Product #8        50        82

# %% [markdown]
# And, here is the second dataset:

# %%
df_hm2
# Out:
#             Store #1  Store #2  Store #3  Store #4  Store #5  Store #6  \
# Product #1        81        10        26        96        22        78
# Product #2        71        10        98        11        38        63
# Product #3        61         7        61        75        13        14
# Product #4        30        71        84        71        62        92
# Product #5        52        82        69        48        86         1
# Product #6        43        51        78        85        63        16
# Product #7        77        49         7         3        10        90
# Product #8        76        38         9        67        31        70
#
#             Store #7  Store #8
# Product #1        18        72
# Product #2        12        30
# Product #3        88        78
# Product #4        64        87
# Product #5        93        21
# Product #6        70        63
# Product #7        57        34
# Product #8        93        28

# %% [markdown]
# The following Python code snippet provides two functions aiming at generating and formatting an annotated heatmap:

# %%
def label_heatmap(im, label_num_dec_place=0):
    labels = im.get_array()
    format_label = f"%.{label_num_dec_place}f"
    textcolors=("black", "white")
    
    # threshold specifying the switch of text color
    threshold = im.norm(labels.max())/2.

    for i in range(labels.shape[0]):
        for j in range(labels.shape[1]):
            text_color = textcolors[int(im.norm(labels[i, j]) > threshold)]            
            text = im.axes.text(j, i, f'{format_label}' % labels[i, j],
                                horizontalalignment="center",
                                verticalalignment="center",
                                color=text_color
                               )

def heatmap(df, ax, cbarlabel="", cmap="Greens", label_num_dec_place=0):
    df = df.copy()
    
    # Ploting a blank heatmap
    im = ax.imshow(df.values, cmap)

    # create a customized colorbar
    cbar = ax.figure.colorbar(im, ax=ax, fraction=0.05, extend='both', extendfrac=0.05)
    cbar.ax.set_ylabel(cbarlabel, rotation=-90, va="bottom", fontsize=18)

    # Setting ticks
    ax.set_xticks(np.arange(df.shape[1]), labels=df.columns, fontsize=16)
    ax.set_yticks(np.arange(df.shape[0]), labels=list(df.index), fontsize=16)

    # proper placement of ticks
    ax.tick_params(axis='x', top=True, bottom=False,
                   labeltop=True, labelbottom=False)

    ax.spines[:].set_visible(False)
    #ax.set_xticks(np.arange(df.shape[1]+1)-.5, minor=True)
    #ax.set_yticks(np.arange(df.shape[0]+1)-.5, minor=True)
    #ax.set_xticks(np.arange(df.shape[1]+1)-0.5, minor=False)
    #ax.set_yticks(np.arange(df.shape[0]+1)-0.5, minor=False)
    #ax.grid(which="both", visible="False", color="white", linestyle='solid', linewidth=2)
    ax.grid(False)
    
    # Rotation of tick labels
    plt.setp(ax.get_xticklabels(), rotation=-60, 
             ha="right", rotation_mode=None)
    plt.setp(ax.get_yticklabels(), rotation=30)
    ax.tick_params(which="minor", bottom=False, left=False)
    
    label_heatmap(im, label_num_dec_place)

# %% [markdown]
# Here is how to use the developed functions above, to produce the annotated heatmaps for sales data for two different time intervals:

# %%
fig, ax = plt.subplots(1,2,figsize=(15,15))
heatmap(df=df_hm1, ax=ax[0], cbarlabel="Sales", cmap="Greens", label_num_dec_place=0)
heatmap(df=df_hm2, ax=ax[1], cbarlabel="Sales", cmap="Blues", label_num_dec_place=0)

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.6, hspace=None)
# Out:
# <ipython-input-62-9a3cd0687d11>:25: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cbar = ax.figure.colorbar(im, ax=ax, fraction=0.05, extend='both', extendfrac=0.05)

# %% [markdown]
# ## Data visualization in Python | visualization with matplotlib | useful resources
#
# There are so many more types of beautiful and insightful plots that you can produce using the low-level library of _matplotlib_.
# You can find very helpful resources consisting of example plots and source codes from the [matplotlib gallery](https://matplotlib.org/stable/gallery/index.html) or [external resources](https://matplotlib.org/stable/users/resources/index.html).

# %% [markdown]
# # Summary
#
# In this tutorial, we discussed some of the important libraries for data visualization in Python including _pandas_, _seaborn_, and _matplotlib_.
#
# You saw that low-level library of _matplotlib_ provides with so many different visualization and formatting features, which allows the creation of highly-complex and informative data visualizations. The downside is that you need to develop a larger amount of code. On the other side, the high-level interfaces such as _pandas_ and _seaborn_ that are wrapped around _matplotlib_ can save you a lot of time in case you want to produce a reasonably well-known type of plot with some available pre-defined formatting configurations. However, some detailed plot formatting may be out of reach of such high-level interfaces, in which case one can resort to the _matplotlib_ directly.
#
# Hopefully, this tutorial was able to help you with data visualization in Python.
# Feel free to check out the rest of our articles from [https://soardeepsci.com/blog/](https://soardeepsci.com/blog/).
